# %% [markdown]
# * Problem : A log of habits in order to keep track of/break habits as desired.
# * Expected Outcome : Loggin a new habit or breaking an existent one
# * Methods : breakHabit, getCategory, action, category, Action
# * Future Modifications : getDate, newHabit (add habits, track by date)

# %%
  import datetime

#class Habit:

  #def __init__(self):
   # self.stack = []

  def breakHabit(hName, startDate):
    #days until broken
    goal = 30
    timeElapsed = (datetime.now - startDate).total_days() 
    

  def getDate():
    return datetime.datetime.now()

  def newHabit(self, data):
   input("Is there a new habit do you want to track?")
   data = input()
   self.stack.append(data)

  def action():
    a = {1: "Log", 2: "Retrieve"}
    for key, value in a.items():

        print("Press", key, "for", value, "\n", end = " ")

    n = int(input("Type the number here"))

    if n > 3:
      print("Error understanding, please select 1, 2, or 3")
      exit()
    else:
      return n


  def getCategory():
    name = {1: "Nutrition", 2: "Inner-Child", 3: "Academic Development"}
    sub = {1: "Food/Meal Prep", 2: "Journaling/Destress", 3 : "Reading 15 mins/day / Podcast"}

    for key, value in name.items():

        print("Press", key, "for", value, "\n", end = " ")

    x = int(input("Type number here "))

    if x > 3:
      print("Error understanding, please select 1, 2, or 3")
      exit()
    else:
      return x


  def category():
    sub = {1: "Food/Meal Prep", 2: "Journaling/Destress", 3 : "Reading 15 mins/day / Podcast"}

    for key, value in sub.items():

        print("Press", key, "for", value, "\n", end = " ")

    y = int(input("Type number here"))

    if y > 3:
      print("Error understanding, please select 1, 2, or 3")
      exit()
    else:
      return y



  def Action(x, n, y):
    if x == 1 and n == 1 and y == 1:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          charmaine.write(str([str(getDate())]) + " : " + value + "\n")
          print("Written sucessfully!")

    elif x == 1 and n == 1 and y == 2:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          charmaine.write(str([str(getDate())]) + " : " + value + "\n")
          print("Written sucessfully!")

    elif x == 1 and n == 1 and y == 3:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          charmaine.write(str([str(getDate())]) + " : " + value + "\n")
          print("Written sucessfully!")

    elif x == 1 and n == 2 and y == 1:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          charmaine.write(str([str(getDate())]) + " : " + value + "\n")
          print("Written sucessfully!")

    elif x == 1 and n == 2 and y == 2:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          charmaine.write(str([str(getDate())]) + " : " + value + "\n")
          print("Written sucessfully!")

    elif x == 1 and n == 2 and y == 3:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          charmaine.write(str([str(getDate())]) + " : " + value + "\n")
          print("Written sucessfully!")

    elif x == 1 and n == 3 and y == 1:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          charmaine.write(str([str(getDate())]) + " : " + value + "\n")
          print("Written sucessfully!")

    elif x == 1 and n == 3 and y == 2:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          charmaine.write(str([str(getDate())]) + " : " + value + "\n")
          print("Written sucessfully!")

    elif x == 1 and n == 3 and y == 3:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          charmaine.write(str([str(getDate())]) + " : " + value + "\n")
          print("Written sucessfully!")

    elif x == 2 and n == 1 and y == 1:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          charmaine.write(str([str(getDate())]) + " : " + value + "\n")
          print("Written sucessfully!")

    elif x == 2 and n == 1 and y == 2:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          charmaine.write(str([str(getDate())]) + " : " + value + "\n")
          print("Written sucessfully!")

    elif x == 2 and n == 1 and y == 3:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          charmaine.write(str([str(getDate())]) + " : " + value + "\n")
          print("Written sucessfully!")

    elif x == 2 and n == 2 and y == 1:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          charmaine.write(str([str(getDate())]) + " : " + value + "\n")
          print("Written sucessfully!")

    elif x == 2 and n == 2 and y == 2:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          a = charmaine.read()
          print(a)

    elif x == 2 and n == 2 and y == 3:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          a = charmaine.read()
          print(a)

    elif x == 2 and n == 3 and y == 1:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          a = charmaine.read()
          print(a)

    elif x == 2 and n == 3 and y == 2:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          a = charmaine.read()
          print(a)

    elif x == 2 and n == 3 and y == 3:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          a = charmaine.read()
          print(a)

    elif x == 3 and n == 1 and y == 1:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          a = charmaine.read()
          print(a)

    elif x == 3 and n == 1 and y == 2:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          a = charmaine.read()
          print(a)

    elif x == 3 and n == 1 and y == 3:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          a = charmaine.read()
          print(a)

    elif x == 3 and n == 2 and y == 1:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          a = charmaine.read()
          print(a)

    elif x == 3 and n == 2 and y == 2:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          a = charmaine.read()
          print(a)

    elif x == 3 and n == 2 and y == 3:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          a = charmaine.read()
          print(a)

    elif x == 3 and n == 3 and y == 1:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          a = charmaine.read()
          print(a)

    elif x == 3 and n == 3 and y == 2:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          a = charmaine.read()
          print(a)

    elif x == 3 and n == 3 and y == 3:
      value = input("Type here \n")

      with open("habit Charmaine.txt", "a") as charmaine:

          a = charmaine.read()
          print(a)

    charmaine.close()

  x = getCategory()
  n = action()
  y = category()
  #z = newHabit()
  Action(x, n, y)
# Out:
# Press 1 for Nutrition
#  Press 2 for Inner-Child
#  Press 3 for Academic Development
#  Type number here 1
# Press 1 for Log
#  Press 2 for Retrieve
#  Type the number here1
# Press 1 for Food/Meal Prep
#  Press 2 for Journaling/Destress
#  Press 3 for Reading 15 mins/day / Podcast
#  Type number here2
# Type here
# y
# Written sucessfully!
